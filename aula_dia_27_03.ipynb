# %% [markdown]
# <a href="https://colab.research.google.com/github/analuizaetec387/PA/blob/main/aula_dia_27_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Estrutura de decisões

#Escrever um programa que compara dois números

a = int (input("digite um numero inteiro: "))

b = int (input("digite um numero inteiro: "))

#processamrnto / saida

if a == b:
  print (f"{a} é igual a {b}")

else:
  print (f"{a} é diferente de {b}")
# Out:
# digite um numero inteiro: 5
# digite um numero inteiro: 6
# 5 é diferente de 6

# %%
# Escrever um programa que verifica se o número digitado é par ou ímpar

# Entrada

numero = int (input("digite um número: "))

# Processamento / saída

if numero % 2 == 0:

  print (f" O número {numero} é par.")

else:
  print (f"O numero {numero} é ímpar")
# Out:
# digite um número: 3
# O numero 3 é ímpar

# %%
# Escreva um programa para descobrir se é criança, adulto ou adolescente

# Entrada

idade = int(input("digite sua idade: "))

# Processamento / saída

if idade <12: print("é criança")

else: print("é adolescente")
# Out:
# digite sua idade: 15
# é adolescente

# %%
#escrever uma calculadora simples

# Entrada

print("|--------calculadora-------|")
print("|--------menu-------|")
print("|                            ")
print("|opção = 1 - soma            |")
print("|opção = 2 - subtração       |")
print("|opção = 3 - multiplicação   |")
print("|opção = 4 - divisão        |")
print("|----------------------------|")

#Entrada

numero = float (input ("digite um numero: "))
opcao = int (input("escolha a opcao desejada: "))
numero1 = float(input ("digite um numero: "))

# Processamento / saida

if opcao == 1:
  print (f"a soma de {numero} e {numero1} é igual a {numero + numero1}:")

# saida

elif opcao == 2:
    print (f"a subtração de {numero} e {numero1} é igual a {numero - numero1}:")

else:
    print ("opcao invalida")
# Out:
# |--------calculadora-------|
# |--------menu-------|
# |
# |opção = 1 - soma            |
# |opção = 2 - subtração       |
# |opção = 3 - multiplicação   |
# |opção = 4 - divisão        |
# |----------------------------|
# digite um numero: 4
# escolha a opcao desejada: 1
# digite um numero: 3
# a soma de 4.0 e 3.0 é igual a 7.0:
