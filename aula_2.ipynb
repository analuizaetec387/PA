# %% [markdown]
# <a href="https://colab.research.google.com/github/analuizaetec387/PA/blob/main/aula_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Aula de Programação e Algoritimo
. Introdução a programação

# %%
print ('olá mundo')
# Out:
# olá mundo

# %% [markdown]
# # Tipos Númericos

# %%
idade = 15

# %%
altura = 1.58

# %%
numero_complexo = 2 + 3j #complex

# %% [markdown]
# # Tipo texto

# %%
nome = 'Ana Luiza' #str

# %% [markdown]
# # Tipo Booleano

# %%
esta_chovendo = False #bool

# %% [markdown]
# # Tipo Lista (mutável)

# %%
numeros = [1, 2, 3, 4, 5,] #List

# %% [markdown]
# # Tipo Tupla

# %%
coordenadas = (10, 20) #tuple

# %% [markdown]
# #Tipo Conjunto

# %%
vogais = {'a', 'e', 'i',
'o', 'u,'} #set

# %% [markdown]
# #Tipo Dicionário

# %%
pessoa = {"nome": "ana luiza", "idade": 15} #dict

# %%
print (f"Nome:"), idade: (idade), Altura: {altura}")
# Out:
#   File "/tmp/ipython-input-721/1411771256.py", line 1
#     print (f"Nome:"), idade: (idade), Altura: {altura}")
#                                                       ^
# SyntaxError: unterminated string literal (detected at line 1)
