# %% [markdown]
# <a href="https://colab.research.google.com/github/analuizaetec387/PA/blob/main/lista.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1
frutas = ["maça", "banana", "laranja", "morango"]
print(frutas)
# Out:
# ['maça', 'banana', 'laranja', 'morango']

# %%
# 2
nomes = ["Rebeca", "Guilherme", "Melissa", "Kyara"]
print(nomes[0])
print(nomes[2])
print(nomes[3])
# Out:
# Rebeca
# Melissa
# Kyara

# %%
# 3
cores = ["vermelho", "Azul", "Verde",]
cores [1] = "amarelo"
print (cores)
# Out:
# ['vermelho', 'amarelo', 'Verde']

# %%
# 4
alunos = ["Nicolas", "Wendel", "Pyetra"]
alunos.append("Petros")
print(alunos)
# Out:
# ['Nicolas', 'Wendel', 'Pyetra', 'Petros']

# %%
# 5
animais = ["cachorro", "gato", "coelho", "passarinho"]
animais.remove("coelho")
print(animais)
# Out:
# ['cachorro', 'gato', 'passarinho']

# %%
# Tuplas 1
meses = ("Janeiro", "Fevereiro", "Março", "Abril")

print(meses)
# Out:
# ('Janeiro', 'Fevereiro', 'Março', 'Abril')

# %%
# 2
numeros = (10, 20, 30, 40, 50)
print(numeros[0])
print(numeros[3])
print(numeros[4])
# Out:
# 10
# 40
# 50

# %%
# 3

aluno = ("Ana", 15, "Informatica")
print(aluno)
# Out:
# ('Ana', 15, 'Informatica')

# %%
# 4
cores = ("vermelho", "Azul", "Verde",)
cores.append("amarelo")
print (cores)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1597/3929814539.py in <cell line: 0>()
#       1 # 4
#       2 cores = ("vermelho", "Azul", "Verde",)
# ----> 3 cores.append("amarelo")
#       4 print (cores)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
# 5
numeros = (2, 4, 2, 6, 2, 8, 10)
print(numeros.count(2))
# Out:
# 3
