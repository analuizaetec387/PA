# %% [markdown]
# <a href="https://colab.research.google.com/github/analuizaetec387/PA/blob/main/funcao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1

def Olá():
  print("Olá Mundo")
Olá()
# Out:
# Olá Mundo

# %%
#2

def mensagem():
  print("Bem vindo ao curso de programação!")
mensagem()
mensagem()
# Out:
# Bem vindo ao curso de programação!
# Bem vindo ao curso de programação!

# %%
#3

def somar():
  soma = 10 + 20
  print(soma)
somar()
# Out:
# 30

# %%
#4

def subtrair():
  resultado = 50 - 15
  print(resultado)
subtrair()
# Out:
# 35

# %%
#5

def multiplicar():
  resultado = 8 * 7
  print(resultado)
multiplicar()
# Out:
# 56

# %%
#6

def cumprimentar(nome):
 print("Olá",nome)
cumprimentar("Ana")
cumprimentar("Gabi")
cumprimentar("Isa")
# Out:
# Olá Ana
# Olá Gabi
# Olá Isa

# %%
#7

def dobro(numero):
  print(numero * 2)
dobro(5)
# Out:
# 10

# %%
#8

def mostrar_idade(idade):
  print("Voce tem", idade, "anos")
mostrar_idade(18)
mostrar_idade(16)
mostrar_idade(19)
# Out:
# Voce tem 18 anos
# Voce tem 16 anos
# Voce tem 19 anos

# %%
#9

def verificar_numero(numero):
  if numero > 0:
    print("positivo")
  elif numero < 0:
    print("negativo")
  else:
    print("zero")
verificar_numero(11)
verificar_numero(-2)
verificar_numero(0)
# Out:
# positivo
# negativo
# zero

# %%
# 10

def calcular_media(nota1,nota2,):
  media = (nota1 + nota2) / 2
  print("a media é",media)
calcular_media(9,7)
# Out:
# a media é 8.0
