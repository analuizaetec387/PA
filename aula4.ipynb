# %% [markdown]
# <a href="https://colab.research.google.com/github/analuizaetec387/PA/blob/main/aula4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de programação e algoritimos
# * Calcular uma área
#
# # Entrada
#
# Ler lado 1
#
# Ler lado 2
#
# #Processamento
#
# area = lado1 * lado2
#
# #Saída
#
# escrever o total da área

# %%
# Variáveis que recebe o valor dos lados

# Entrada
lado1 = 7
lado2 = 3

# %%
# Processamento

area = lado1 * lado2

# %%
# Saída

print (f"Total da area calculada: {area} metros quadrados")
# Out:
# Total da area calculada: 21 metros quadrados

# %% [markdown]
# Operadores aritiméticos:
#
#
#
# 1.   Soma = +
# 2.   Subtração = -
# 3.   Multiplicação = *
# 4.   Divisão = /

# %% [markdown]
# Atividade:
#
# Fazer um algoritimo e depois o programa que recebe 4 notas do aluno e calcula a média aritimética e imprimi a média

# %%
# Nota do aluno

# Entrada

nota1 = 8
nota2 = 9
nota3 = 5
nota4 = 7

# %%
# Processamento

media = nota1 + nota2 + nota3 + nota4
Resultado = media /4

# %%
print (f"Nota final do aluno: {Resultado}")
# Out:
# Nota final do aluno: 7.25

# %% [markdown]
# Faça um algoritimo que receba um número ecalcule o dobro desse número

# %%
# variaveis que recebe um valor e depois calcula o seu dobro

# Entras

numero = 10

# %%
# Processamento
total = 10 * 2

# %%
# Saída

print (f"Valor final: {total}")
# Out:
# Valor final: 20
