# %% [markdown]
# <a href="https://colab.research.google.com/github/analuizaetec387/PA/blob/main/aula2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1

idade = int(input("digite sua idade: "))

if idade >=18: print("Voce pode tirar a carteira")

else:
  print("Não pode tirar a carteira")
# Out:
# digite sua idade: 19
# Voce pode tirar a carteira

# %%
# 2

numero = int (input("digite um número: "))

if numero % 2 == 0:

  print (f" O número {numero} é par.")

else:
  print (f"O numero {numero} é ímpar")
# Out:
# digite um número: 8
#  O número 8 é par.

# %%
# 3

numero1 = float (input("digite o primeiro número: "))
numero2 = float (input("digite o segundo número: "))

if numero1 > numero2:
  print("O maior numero é:", numero1)

elif numero2 > numero1:
  print("O maior numero é:", numero2)

else:
  print("Os numeros são iguais")
# Out:
# digite o primeiro número: 7
# digite o segundo número: 9
# O maior numero é: 9.0

# %%
# 4

nota1 = float (input("Digite a nota do primeiro bimestre: "))

if nota1 < 0 or nota1 > 10:
  print ("nota inválida, digite uma nota de 0 a 10:")
  nota1 = float (input("Digite a nota do primeiro bimestre: "))

nota2 = float (input("Digite a nota do segundo bimestre: "))

if nota2 < 0 or nota1 > 10:
  print ("nota inválida, digite uma nota de 0 a 10:")
  nota2 = float (input("Digite a nota do segundo bimestre: "))

nota3 = float (input("Digite a nota do terceiro bimestre: "))

if nota3 < 0 or nota1 > 10:
  print ("nota inválida, digite uma nota de 0 a 10:")
  nota2 = float (input("Digite a nota do terceiro bimestre: "))

nota4 = float (input("Digite a nota do quarto bimestre: "))

if nota4 < 0 or nota1 > 10:
  print ("nota inválida, digite uma nota de 0 a 10:")
  nota4 = float (input("Digite a nota do quarto bimestre: "))

media = (nota1 + nota2 + nota3 + nota4)/4

if media < 5:
 print (f"reprovado, sua média é {media}")

elif media <= 7:
  print (f"recuperação, sua média é {media}")

else:
  print (f"aprovado, sua média é {media}")
# Out:
# Digite a nota do primeiro bimestre: 9
# Digite a nota do segundo bimestre: 10
# Digite a nota do terceiro bimestre: 4
# Digite a nota do quarto bimestre: 8
# aprovado, sua média é 7.75

# %%
# 5

valor = float(input("Digite o valor da compra: "))

if valor >= 100:
    desconto = valor * 10 / 100
    valor_final = valor - desconto
    print("O valor com desconto é:", valor_final)
else:
    print("O valor da compra é:", valor)
# Out:
# Digite o valor da compra: 206
# O valor com desconto é: 185.4

# %%
# 6

numero = float(input("Digite um número: "))

# Processamento/saida

if numero > 0:
  print("Positivo")

elif numero < 0:
        print("Negativo")

else:
  print("Zero")
# Out:
# Digite um número: 6
# Positivo

# %%
# 7

idade = int(input("Digite sua idade: "))

if idade < 12:
    print("Criança")
elif idade <= 17:
    print("Adolescente")
elif idade <= 59:
    print("Adulto")
else:
    print("Idoso")
# Out:
# Digite sua idade: 15
# Adolescente

# %%
# 8

nota1 = float (input("Digite a nota do primeiro bimestre: "))

nota2 = float (input("Digite a nota do segundo bimestre: "))

if media < 5:
  print (f"recuperação, sua média é {media}")

else:
  print (f"aprovado, sua média é {media}")
# Out:
# Digite a nota do primeiro bimestre: 9
# Digite a nota do segundo bimestre: 7
# aprovado, sua média é 7.75

# %%
# 9

usuario = input("Digite o usuário: ")
senha = input("Digite a senha: ")

if usuario == "admin":
  if senha == "1234":
    print("login realizado com sucesso")
else:
    print("usuario ou senha incorretos")
# Out:
# Digite o usuário: ana
# Digite a senha: 1903
# usuario ou senha incorretos

# %%
# 10

peso = float(input("Digite seu peso: "))
altura = float(input("Digite sua altura: "))

imc = peso / (altura * altura)

print(f"Seu IMC é: {imc}")

if imc < 18.5:
    print("Esta abaixo do peso")
elif 18.5 <= imc <= 24.9:
    print("Esta com peso normal")
elif 25 <= imc <= 29.9:
    print("Esta com sobrepeso")
else:
    print("Esta com obesidade")
# Out:
# Digite seu peso: 48
# Digite sua altura: 158
# Seu IMC é: 0.0019227687870533568
# Esta abaixo do peso
